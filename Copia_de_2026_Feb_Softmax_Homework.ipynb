# %% [markdown]
# <a href="https://colab.research.google.com/github/maticas444/Google-Colab/blob/main/Copia_de_2026_Feb_Softmax_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# Datos sintéticos

np.random.seed(45)

n = 2   # features
m = 40 # más datos ayuda
C = 3   # clases

# Datos de entrada
noise_level = 0.3
X = np.random.randn(n, m)

# Parámetros reales (que el modelo debería aprender)
W_real = np.random.randn(C, n)
b_real = np.random.randn(C, 1)

# Generar logits reales
Z = W_real @ X + b_real

# Softmax
def softmax2(Z):
    expZ = np.exp(Z - np.max(Z, axis=0, keepdims=True))
    return expZ / np.sum(expZ, axis=0, keepdims=True)

A = softmax2(Z)

# Clases reales
Y = np.argmax(A, axis=0)

# One-hot
Yhot = np.eye(C)[Y].T

#print(f"X[0:10] = {X}")  # Mostrar para m = 5
#print(f"Y[0:10] = {Y}")

# %%
def cost(Y,Yhat):
  # Retorna el cost
  return cost

# %%
def softmax(X,W,B):
  # Retorna la prediccion Yhat
  return Yhat

# %%
def gradient(Yhot,Yhat,X):
  # Retorna dW, dB
  return dW, dB

# %%
def softmax_to_class(Yhat):
    # Pasa de probabilidades Yhat en one hot a Ypredict categorical
    return Ypredict

# %%
# Finalizado
def accuracy_score(Y, Ypredict):
    return np.mean(Y == Ypredict)  # Retorna el Accuracy

# %%
# Algoritmo de Entrenamiento
